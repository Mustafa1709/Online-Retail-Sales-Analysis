# %%
import pandas as pd
pd.set_option("display.max_rows", None)

# %%
retail = pd.read_csv("online_retail_real_world.csv")

# %%
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                     Brand Raw_Weight  \
# 0                   Perly      100 g
# 1                      LU      300 g
# 2  Lindt EXCELLENCE,Lindt       100g
# 3                    عربي       22 g
# 4                  Gerblé       230g
# ...

# %%
retail.columns
# Out:
# Index(['OrderID', 'CustomerID', 'ProductName', 'Brand', 'Raw_Weight',
#        'Country', 'OrderDate', 'UnitPrice'],
#       dtype='object')

# %%
retail['Brand'].unique()
# Out:
# array(['Perly', 'LU', 'Lindt EXCELLENCE,Lindt', ..., 'San Carlo',
#        'Santiveri', 'Higgidy'], dtype=object)

# %%
retail['Brand'] = retail['Brand'].str.replace(r"[.]","",regex = True)

# %%
retail['Brand'].unique()
# Out:
# array(['Perly', 'LU', 'Lindt EXCELLENCE,Lindt', ..., 'San Carlo',
#        'Santiveri', 'Higgidy'], dtype=object)

# %%
retail['ProductName'].unique()
# Out:
# array(['Perly', 'Prince Goût Chocolat',
#        'Excellence Noir Prodigieux 90% Cacao', ..., 'Lait dessert',
#        'Rusticotti', 'Cheddar & Onion Chutney Rolls'], dtype=object)

# %%
retail['ProductName']=retail['ProductName'].str.strip("Ã©~`@!#$%^&*()_=/*-+<>?:|1234567890")
retail.head(5)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
#
#                     Brand Raw_Weight  \
# 0                   Perly      100 g
# 1                      LU      300 g
# 2  Lindt EXCELLENCE,Lindt       100g
# 3                    عربي       22 g
# 4                  Gerblé       230g
#
#                                              Country   OrderDate  UnitPrice
# 0                              Morocco,United States  2024-02-22      13.18
# 1  Algeria,Belgium,France,French Polynesia,German...  2024-11-13       1.50
# 2  Argelia,Austria,Bélgica,Bulgaria,Canadá,Repúbl...  2025-02-02      12.99
# ...

# %%
retail['Brand']=retail['Brand'].str.strip("Ã©~`@!#$%^&*()_=/*-+<>?:|1234567890")
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                     Brand Raw_Weight  \
# 0                   Perly      100 g
# 1                      LU      300 g
# 2  Lindt EXCELLENCE,Lindt       100g
# 3                    عربي       22 g
# 4                  Gerblé       230g
# ...

# %%
retail['Country']=retail['Country'].str.strip("Ã©~`@!#$%^&*()_=/*-+<>?:|1234567890")
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                     Brand Raw_Weight  \
# 0                   Perly      100 g
# 1                      LU      300 g
# 2  Lindt EXCELLENCE,Lindt       100g
# 3                    عربي       22 g
# 4                  Gerblé       230g
# ...

# %%
retail['Raw_Weight']=retail['Raw_Weight'].str.strip("Ã©~`@!#$%^&*()_=/*-+<>?:|")
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                     Brand Raw_Weight  \
# 0                   Perly      100 g
# 1                      LU      300 g
# 2  Lindt EXCELLENCE,Lindt       100g
# 3                    عربي       22 g
# 4                  Gerblé       230g
# ...

# %%
retail[retail["Raw_Weight"].isnull()]
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                     Brand Raw_Weight  \
# 0                   Perly      100 g
# 1                      LU      300 g
# 2  Lindt EXCELLENCE,Lindt       100g
# 3                    عربي       22 g
# 4                  Gerblé       230g
# ...

# %%
retail.isnull().sum() *100/len(retail)
# Out:
# OrderID         0.000000
# CustomerID      0.000000
# ProductName     3.200000
# Brand          11.166667
# Raw_Weight     17.066667
# Country         0.000000
# OrderDate       0.000000
# UnitPrice      12.833333
# dtype: float64

# %%
retail['Raw_Weight'].fillna('Subjective', inplace=True)
retail["Raw_Weight"].value_counts()
#retail["Raw_Weight"] = retail["Raw_Weight"].str.replace(r"\s*g", "g", regex=True)
#retail['Raw_Weight'] = retail["Raw_Weight"].str.replace("Subjective","Not Specified" ,regex=True)
retail.columns
#retail["OrderID"].value_counts()
#retail["CustomerID"].value_counts()
retail["ProductName"].value_counts()
retail["Brand"].value_counts()
retail.dtypes
# Out:
# C:\Users\Mohammed mustafa\AppData\Local\Temp\ipykernel_15076\1156683721.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   retail['Raw_Weight'].fillna('Subjective', inplace=True)
# OrderID         object
# CustomerID       int64
# ProductName     object
# Brand           object
# Raw_Weight      object
# Country         object
# OrderDate       object
# UnitPrice      float64
# dtype: object

# %%
retail[retail["UnitPrice"].isnull()]
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                     Brand Raw_Weight  \
# 0                   Perly      100 g
# 1                      LU      300 g
# 2  Lindt EXCELLENCE,Lindt       100g
# 3                    عربي       22 g
# 4                  Gerblé       230g
# ...

# %%
retail['UnitPrice'].fillna('Notknown', inplace=True)
# Out:
# C:\Users\Mohammed mustafa\AppData\Local\Temp\ipykernel_15076\2778757500.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   retail['UnitPrice'].fillna('Notknown', inplace=True)
# C:\Users\Mohammed mustafa\AppData\Local\Temp\ipykernel_15076\2778757500.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Notknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# ...

# %%
retail[retail["Brand"].isnull()]
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                     Brand Raw_Weight  \
# 0                   Perly      100 g
# 1                      LU      300 g
# 2  Lindt EXCELLENCE,Lindt       100g
# 3                    عربي       22 g
# 4                  Gerblé       230g
# ...

# %%
retail['Brand'].fillna('Notknown', inplace=True)
# Out:
# C:\Users\Mohammed mustafa\AppData\Local\Temp\ipykernel_15076\4130042966.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   retail['Brand'].fillna('Notknown', inplace=True)

# %%
retail[retail["ProductName"].isnull()]
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                     Brand Raw_Weight  \
# 0                   Perly      100 g
# 1                      LU      300 g
# 2  Lindt EXCELLENCE,Lindt       100g
# 3                    عربي       22 g
# 4                  Gerblé       230g
# ...

# %%
retail["ProductName"].fillna("NotKnown",inplace=True)
# Out:
# C:\Users\Mohammed mustafa\AppData\Local\Temp\ipykernel_15076\2477292438.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   retail["ProductName"].fillna("NotKnown",inplace=True)

# %%
retail["Raw_Weight"] = retail["Raw_Weight"].str.replace(r"\s/-grams","g",regex=True,case=False)
retail["Raw_Weight"] = retail["Raw_Weight"].str.replace(r"unknown","g",regex=True,case=False)

# %%
retail["Raw_Weight"].value_counts()
retail["Raw_Weight"].unique()
# Out:
# array(['100 g', '300 g', '100g', '22 g', '230g', '125g', '500 ml', '42g',
#        '150 g', '90g', 'Subjective', '304 g', '275 g', '150g', '225 g',
#        '100 gram', '230 g', '85 g', '36 g', '52', '160 g', '20g', '42 g',
#        '210 g', '50g', '205g', '350 g', '400 g', '200 g', '500 g',
#        '165 g', '200 g e', '250', '270 g', '7.35 gram', '130 g', '285 g',
#        '360g', '160 g (4x40 g', '192 g (12 x 16 g', '350g',
#        '210 g, 5 barres doubles de 42 g', '1 klg', '435 g', '165g',
#        '485 g', '122 g', '40g', '425 g', '180 g', '140 g', '22g', '360 g',
#        'n.48 - 912g', '135 g', '350 g ℮', '3 sachets de 4 biscuits, 250g',
#        '300 g 15.5', '39 g', '180 g (6 x 30 g', '250 g', '4 x 35g', '52g',
#        '440 g', '150 g (12x 12.5 g) e', '170 g', '28 gram', '260 g',
#        '145 g', '100 g (10 carrés', '8 biscuits', '150 g ℮', '720g - 36',
#        '184g', '185g', '400 gram', '1.5g', '125 g', '276 g', '90 g',
# ...

# %%
retail[retail["OrderID"].duplicated(keep=False)]
# Out:
#          OrderID  CustomerID  \
# 574   REC-189159       13071
# 944   REC-127088       12111
# 1129  REC-660334       12862
# 1242  REC-828818        6623
# 1311  REC-133930       12583
# 1314  REC-660334        5314
# 1320  REC-388577       12823
# 1443  REC-771999        8170
# 1535  REC-133930       12702
# 1942  REC-189159       13365
# 2216  REC-828818        6585
# 2389  REC-913871        5740
# 2492  REC-388577       13112
# 2655  REC-771999       14873
# 2657  REC-913871        5585
# 2724  REC-127088        5338
#
#                                             ProductName  \
# 574                       RASPBERRY WHOLEGRAIN OAT BARS
# 944                               Toetilla Chips Nature
# 1129                              Création Crème Brûlée
# 1242                         Bruges Assortment Biscuits
# 1311                              Tartelettes framboise
# 1314                               Pains au chocolat x
# 1320                               Doritos Tangy Cheese
# ...

# %%
retail[["Country","Other Countries"]] = retail["Country"].str.split(",",n =1,expand=True)

# %%
retail["Country"] = retail["Country"].str.strip()
retail["Other Countries"] = retail["Other Countries"].str.strip()

# %%
retail["Country"] = retail["Country"].str.replace("Francia","France",regex=True)

# %%
retail["Country"] = retail["Country"].str.replace("en:","",regex= True)
retail["Country"] = retail["Country"].str.replace(":","",regex= True)

# %%
retail[retail["Country"] == "fr"]
retail["Country"].str.replace("fr","France",regex=True)
retail.head(5)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
#
#                     Brand Raw_Weight  Country   OrderDate UnitPrice  \
# 0                   Perly      100 g  Morocco  2024-02-22     13.18
# 1                      LU      300 g  Algeria  2024-11-13       1.5
# 2  Lindt EXCELLENCE,Lindt       100g  Argelia  2025-02-02     12.99
# 3                    عربي       22 g    Maroc  2024-12-11     14.82
# 4                  Gerblé       230g  Belgium  2025-08-21      18.4
#
#                                      Other Countries
# 0                                      United States
# 1  Belgium,France,French Polynesia,Germany,Guadel...
# ...

# %%
retail["Country"].str.replace("Белгия","Belgium",regex=True)
# Out:
# 0                      Morocco
# 1                      Algeria
# 2                      Argelia
# 3                        Maroc
# 4                      Belgium
# 5                      Austria
# 6                      Belgium
# 7                        Maroc
# 8                      Algeria
# 9                       France
# 10                     Morocco
# 11                       Maroc
# 12                      France
# 13                      France
# 14                     Algérie
# 15                      France
# 16                     Belgium
# 17                    Autriche
# 18                      France
# 19                     Belgium
# 20                    Belgique
# 21                       Maroc
# 22                       Maroc
# 23                     Austria
# 24                   Australie
# 25                     Morocco
# 26                     Belgium
# 27                     Belgium
# 28                       Spain
# 29                          DE
# ...

# %%
retail["Country"].unique()
# Out:
# array(['Morocco', 'Algeria', 'Argelia', 'Maroc', 'Belgium', 'Austria',
#        'France', 'Algérie', 'Autriche', 'Belgique', 'Australie', 'Spain',
#        'DE', 'Italia', 'Bélgica', 'Australia', 'ma', 'Algieria',
#        'United Kingdom', 'Armenia', 'België', 'Israel', 'Germany',
#        'united-kingdom', 'Bulgaria', 'Portugal', 'france', 'belgium',
#        'Finland', 'Ireland', 'Francuska', 'Frankreich', 'Belgien',
#        'Bulgarie', 'Deutschland', 'Canada', 'Frankrijk', 'gb',
#        'Royaume-Uni', 'España', 'Armenien', 'fr', 'Dänemark', 'Croatie',
#        'Lebanon', 'Croatia', 'Franța', '奥地利', 'New Zealand', 'Italy',
#        'Marruecos', 'Czech Republic', 'morocco', 'ประเทศออสเตรีย',
#        'Isle of Man', 'Österreich', 'andorra', 'Australien', 'Qatar',
#        'Bolivia', 'Hungary', 'Tschechien', 'Франция', 'Greece', 'hungary',
#        'United States', 'Hong Kong', 'République tchèque', 'An Fhraing',
#        '保加利亚', 'França', 'Saudi Arabia', 'Bulgarije', 'Argélia',
# ...

# %%
retail[retail["Country"]=="奥地利"]
# Out:
#         OrderID  CustomerID   ProductName           Brand  Raw_Weight Country  \
# 327  REC-110119        5506  Cake & Chock  Milka,Mondelēz  Subjective     奥地利
#
#       OrderDate UnitPrice                            Other Countries
# 327  2025-08-31  Notknown  比利时,爱沙尼亚,法国,德国,意大利,拉脫維亞,立陶宛,荷蘭,波兰,葡萄牙,匈牙利

# %%
retail["Country"].str.replace("奥地利","Austria",regex=True)
# Out:
# 0                      Morocco
# 1                      Algeria
# 2                      Argelia
# 3                        Maroc
# 4                      Belgium
# 5                      Austria
# 6                      Belgium
# 7                        Maroc
# 8                      Algeria
# 9                       France
# 10                     Morocco
# 11                       Maroc
# 12                      France
# 13                      France
# 14                     Algérie
# 15                      France
# 16                     Belgium
# 17                    Autriche
# 18                      France
# 19                     Belgium
# 20                    Belgique
# 21                       Maroc
# 22                       Maroc
# 23                     Austria
# 24                   Australie
# 25                     Morocco
# 26                     Belgium
# 27                     Belgium
# 28                       Spain
# 29                          DE
# ...

# %%
retail["Country"].unique()
country_map = {
    "Algelia":"Algeria",
    "Algérie":"Algeria",
    "Algieria":"Algeria",
    "Maroc":"Morocco",
    "Autriche":"Austria",
    "Australie":"Australia",
    "Australi":"Australia",
    "Belgique":"Belgium",
    "Belgique":"Belgium",
    "España":"Spain",
    "Frankreich":"France",
    "Frankrijk":"France",
    "Bélgica":"Belgium",
    "Österreich":"Austria",
    "france":"France",
   "Deutschland":"Germany",
   "Marruecos":"Morocco",
   "morocco":"Morocco",
   "Italia":"Italy",
   "Royaume-Uni":"United Kingdom",
   "united-kingdom":"United Kingdom",
   "België":"Belgium",
   "Франция":"France",
   "França":"France",
   "Belgi":"Belgium",
   "Dinamarca":"Denmark",
   "Белгия":"Belgium",
   "Argelia":"Algeria",
   "":"unknown",
   "Francuska":"France",
   "Bulgarie":"Bulgaria",
   "Dänemark":"Denmark",
   "Croatie":"Croatia",
   "Franța":"France",
   "Fr":"France",
   "Ma":"Mexico",
   "Gb":"United Kingdom",
   "De":"Denmark",
   "Belgien":"Belgium",
   "Armenien":"Armenia",
   "ประเทศออสเตรีย":"Austria",
   "Tschechien":"Czech Republic",
   "République Tchèque":"Czech Republic",
   "An Fhraing":"France",
   "保加利亚":"Bulgaria",
   "Bulgarije":"Bulgaria",
   "Argélia":"Algeria",
   "Rumania":"Romania",
   "Espanha":"Spain",
   "Reino Unido":"United Kingdom",
   "Spagna":"Spain",
   "Finlândia":"Finland",
   "Alemanha":"Germany",
   "Verenigd Koninkrijk":"United Kingdom",
   "Bulgarien":"Bulgaria",
   "Allemagne":"Germany",
   "法国":"France",
   "Hrvatska":"Croatia",
   "Danmark":"Denmark",
   "Bosnie-Herzégovine":"Bosnia and Herzegovina",
   "ประเทศฝรั่งเศส":"France",
   "República Checa":"Czech Republic" }
retail["Country"] = retail["Country"].replace(country_map)
retail["Country"].unique()
retail["Country"] = retail["Country"].str.strip().str.title()
# Out:
# array(['Morocco', 'Algeria', 'Belgium', 'Austria', 'France', 'Australia',
#        'Spain', 'De', 'Italy', 'Ma', 'United Kingdom', 'Armenia',
#        'Israel', 'Germany', 'Bulgaria', 'Portugal', 'Finland', 'Ireland',
#        'Canada', 'Gb', 'Fr', 'Denmark', 'Croatia', 'Lebanon', '奥地利',
#        'New Zealand', 'Czech Republic', 'Isle Of Man', 'Andorra',
#        'Australien', 'Qatar', 'Bolivia', 'Hungary', 'Greece',
#        'United States', 'Hong Kong', 'République Tchèque', 'Saudi Arabia',
#        'Romania', 'Tunisia', 'Switzerland', 'Bosnia And Herzegovina',
#        'Netherlands', 'Ge', 'Belarus', 'It', 'India', 'Egypt',
#        'Åland Islands', 'الجزائر', 'Cape-Verde', 'Russia', 'Belgie',
#        'Alemania', 'Argentina', 'Brazil', 'Us', 'Finlande', 'Poland',
#        'Albania', 'Horvátország', 'Болгария', 'Чехия', 'Ranska', 'Belgia',
#        'Inde', 'Senegal', 'Marokko', 'Vereinigtes Königreich', 'Itit',
# ...

# %%
retail["Country"].unique()
country_map = {
    "Algelia":"Algeria",
    "Algérie":"Algeria",
    "Algieria":"Algeria",
    "Maroc":"Morocco",
    "Autriche":"Austria",
    "Australie":"Australia",
    "Australi":"Australia",
    "Belgique":"Belgium",
    "Belgique":"Belgium",
    "España":"Spain",
    "Frankreich":"France",
    "Frankrijk":"France",
    "Bélgica":"Belgium",
    "Österreich":"Austria",
    "france":"France",
   "Deutschland":"Germany",
   "Marruecos":"Morocco",
   "morocco":"Morocco",
   "Italia":"Italy",
   "Royaume-Uni":"United Kingdom",
   "united-kingdom":"United Kingdom",
   "België":"Belgium",
   "Франция":"France",
   "França":"France",
   "Belgi":"Belgium",
   "Dinamarca":"Denmark",
   "Белгия":"Belgium",
   "Argelia":"Algeria",
   "":"unknown",
   "Francuska":"France",
   "Bulgarie":"Bulgaria",
   "Dänemark":"Denmark",
   "Croatie":"Croatia",
   "Franța":"France",
   "Fr":"France",
   "Ma":"Mexico",
   "Gb":"United Kingdom",
   "De":"Denmark",
   "Belgien":"Belgium",
   "Armenien":"Armenia",
   "ประเทศออสเตรีย":"Austria",
   "Tschechien":"Czech Republic",
   "République Tchèque":"Czech Republic",
   "An Fhraing":"France",
   "保加利亚":"Bulgaria",
   "Bulgarije":"Bulgaria",
   "Argélia":"Algeria",
   "Rumania":"Romania",
   "Espanha":"Spain",
   "Reino Unido":"United Kingdom",
   "Spagna":"Spain",
   "Finlândia":"Finland",
   "Alemanha":"Germany",
   "Verenigd Koninkrijk":"United Kingdom",
   "Bulgarien":"Bulgaria",
   "Allemagne":"Germany",
   "法国":"France",
   "Hrvatska":"Croatia",
   "Danmark":"Denmark",
   "Bosnie-Herzégovine":"Bosnia and Herzegovina",
   "ประเทศฝรั่งเศส":"France",
   "República Checa":"Czech Republic",
   "Us":"United States Of America",
   "Horvátország":"Croatia",
    "Болгария":"Bulgaria",
     "Чехия":"Czech Republic",
      "Ranska":"France",
       "Inde":"India",
        "Marokko":"Morocco",
        "Vereinigtes Königreich":"United Kingdom",
        "Alemania":"Armenia",
        "Serbien":"Serbia",
        "Румъния":"Romania",
        "Nederland":"Netherlands",
        "Australien":"Australia",
        "Espagne":"Spain",
        "България":"Bulgaria",
        "Brazil  France":"Brazil",
        "Be":"Belgium",
        "Spanien":"Spain",
        "Finlandia":"Finland",
        "Estados Unidos":"United States Of America",
        "United States":"United States Of America",







   





   





   }
retail["Country"] = retail["Country"].replace(country_map)
retail["Country"].unique()
retail["Country"] = retail["Country"].str.strip().str.title()
retail["Country"].unique()
# Out:
# array(['Morocco', 'Algeria', 'Belgium', 'Austria', 'France', 'Australia',
#        'Spain', 'Denmark', 'Mexico', 'United Kingdom', 'Armenia',
#        'Israel', 'Germany', 'Bulgaria', 'Portugal', 'Finland', 'Ireland',
#        'Canada', 'Lebanon', 'New Zealand', 'Czech Republic', 'Italy',
#        'Croatia', 'Isle Of Man', 'Andorra', 'Hungary', 'Greece',
#        'United States Of America', 'Saudi Arabia', 'Qatar', 'Romania',
#        'Tunisia', 'Switzerland', 'Bolivia', 'Bosnia And Herzegovina',
#        'Netherlands', 'Belarus', 'It', 'India', 'Egypt', 'Åland Islands',
#        'Cape-Verde', 'Russia', 'Argentina', 'Brazil', 'Poland', 'Albania',
#        'Senegal', 'Itit', 'Turkey', 'Serbia', 'Chile', 'European Union',
#        'Jersey', 'China', 'Guernsey'], dtype=object)

# %%
pd.set_option("display.max_rows", None)
print(retail["Country"].value_counts())
# Out:
# Country
# France                      1611
# United Kingdom               366
# Belgium                      243
# Morocco                      137
# Spain                         85
# Germany                       75
# Austria                       56
# Bulgaria                      52
# Italy                         39
# Mexico                        33
# United States                 31
# Australia                     29
# Algeria                       27
# Czech Republic                24
# Portugal                      24
# Ireland                       20
# Canada                        16
# Romania                       12
# Croatia                       12
# Bolivia                       10
# Denmark                        9
# India                          8
# Finland                        8
# Hungary                        5
# Switzerland                    5
# Armenia                        4
# Netherlands                    4
# United States Of America       4
# ...

# %%
retail["Country"].value_counts()
# Out:
# Country
# France                      1611
# United Kingdom               366
# Belgium                      243
# Morocco                      137
# Spain                         85
# Germany                       75
# Austria                       56
# Bulgaria                      52
# Italy                         39
# Mexico                        33
# United States                 31
# Australia                     29
# Algeria                       27
# Czech Republic                24
# Portugal                      24
# Ireland                       20
# Canada                        16
# Romania                       12
# Croatia                       12
# Bolivia                       10
# Denmark                        9
# India                          8
# Finland                        8
# Hungary                        5
# Switzerland                    5
# Armenia                        4
# Netherlands                    4
# United States Of America       4
# ...

# %%
retail[retail.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerID, ProductName, Brand, Raw_Weight, Country, OrderDate, UnitPrice, Other Countries]
# Index: []

# %%
retail["Country"].value_counts().head(30)
# Out:
# Country
# France                      1611
# United Kingdom               366
# Belgium                      243
# Morocco                      137
# Spain                         85
# Germany                       75
# Austria                       56
# Bulgaria                      52
# Italy                         39
# Mexico                        33
# United States                 31
# Australia                     29
# Algeria                       27
# Czech Republic                24
# Portugal                      24
# Ireland                       20
# Canada                        16
# Romania                       12
# Croatia                       12
# Bolivia                       10
# Denmark                        9
# India                          8
# Finland                        8
# Hungary                        5
# Switzerland                    5
# Armenia                        4
# Netherlands                    4
# United States Of America       4
# ...

# %%
retail["OrderID"].duplicated().sum()
# Out:
# 8

# %%
retail.dtypes
# Out:
# OrderID            object
# CustomerID          int64
# ProductName        object
# Brand              object
# Raw_Weight         object
# Country            object
# OrderDate          object
# UnitPrice          object
# Other Countries    object
# dtype: object

# %%
retail[retail["Country"]=="Ma"]
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                     Brand Raw_Weight  Country   OrderDate UnitPrice  \
# 0                   Perly      100 g  Morocco  2024-02-22     13.18
# 1                      LU      300 g  Algeria  2024-11-13       1.5
# ...

# %%
retail["ProductName"] = retail["ProductName"].str.replace(
    r"[\U00010000-\U0010FFFF]",
    "",
    regex=True
)

# %%
retail["ProductName"] = retail["ProductName"].str.strip()

# %%
retail = retail.drop(columns = 'Other Countries')

# %%
retail
retail["Brand"].unique()
# Out:
# array(['Perly', 'LU', 'Lindt EXCELLENCE,Lindt', ..., 'San Carlo',
#        'Santiveri', 'Higgidy'], dtype=object)

# %%
retail["Brand"].isnull().any()
# Out:
# False

# %%
retail[retail["Brand"].isnull()]
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerID, ProductName, Brand, Raw_Weight, Country, OrderDate, UnitPrice]
# Index: []

# %%
retail.head(20)
# Out:
#        OrderID  CustomerID                                       ProductName  \
# 0   REC-861088        6120                                             Perly
# 1   REC-900952       12550                              Prince Goût Chocolat
# 2   REC-595965        6705              Excellence Noir Prodigieux 90% Cacao
# 3   REC-942653        8645                                             Tonik
# 4   REC-885998       14430                                            Sésame
# 5   REC-674324        6760                          Шоколад 85% какаова маса
# 6   REC-867660        8420                     CRISTALINE Eau De Source 0.5L
# 7   REC-448132        9144                                           Henry’s
# 8   REC-202400       10397                                Milk chocolate bar
# 9   REC-386572       13888                    Organic 70% Dark Chocolate Bar
# 10  REC-394893        8397                                      KING COOKIES
# ...

# %%
# converting to the date time
retail["OrderDate"] = pd.to_datetime(retail["OrderDate"])

# %%
retail["OrderDate"].dtype
# Out:
# dtype('<M8[ns]')

# %%
retail.isnull().sum()
# Out:
# OrderID        0
# CustomerID     0
# ProductName    0
# Brand          0
# Raw_Weight     0
# Country        0
# OrderDate      0
# UnitPrice      0
# dtype: int64

# %%
retail["Brand"] = retail["Brand"].str.replace(r"[^A-Za-z ]", "", regex=True)

# %%
retail["Brand"] = retail["Brand"].str.strip()

# %%
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                    Brand Raw_Weight  Country  OrderDate UnitPrice
# 0                  Perly      100 g  Morocco 2024-02-22     13.18
# 1                     LU      300 g  Algeria 2024-11-13       1.5
# ...

# %%
retail["ProductName"].unique()
# Out:
# array(['Perly', 'Prince Goût Chocolat',
#        'Excellence Noir Prodigieux 90% Cacao', ..., 'Lait dessert',
#        'Rusticotti', 'Cheddar & Onion Chutney Rolls'], dtype=object)

# %%
retail["ProductName"].str.strip()
# Out:
# 0                                                   Perly
# 1                                    Prince Goût Chocolat
# 2                    Excellence Noir Prodigieux 90% Cacao
# 3                                                   Tonik
# 4                                                  Sésame
# 5                                Шоколад 85% какаова маса
# 6                           CRISTALINE Eau De Source 0.5L
# 7                                                 Henry’s
# 8                                      Milk chocolate bar
# 9                          Organic 70% Dark Chocolate Bar
# 10                                           KING COOKIES
# 11                                 Sable coco Henry s 42g
# 12       Biscuits croquants au coeur onctueux de Nutella®
# 13                      Tartine croustillante Authentique
# 14                      Excellence Noir Intense 70% Cacao
# 15                              Lightly sea salted crisps
# ...

# %%
retail["ProductName"] = retail["ProductName"].str.replace(
    r"[\U00010000-\U0010FFFF]",
    "",
    regex=True
)

# %%
retail["ProductName"] = retail["ProductName"].str.replace(r"\s+", " ", regex=True)

# %%
retail.head(20)
# Out:
#        OrderID  CustomerID                                       ProductName  \
# 0   REC-861088        6120                                             Perly
# 1   REC-900952       12550                              Prince Goût Chocolat
# 2   REC-595965        6705              Excellence Noir Prodigieux 90% Cacao
# 3   REC-942653        8645                                             Tonik
# 4   REC-885998       14430                                            Sésame
# 5   REC-674324        6760                          Шоколад 85% какаова маса
# 6   REC-867660        8420                     CRISTALINE Eau De Source 0.5L
# 7   REC-448132        9144                                           Henry’s
# 8   REC-202400       10397                                Milk chocolate bar
# 9   REC-386572       13888                    Organic 70% Dark Chocolate Bar
# 10  REC-394893        8397                                      KING COOKIES
# ...

# %%
retail.isnull().sum()
# Out:
# OrderID        0
# CustomerID     0
# ProductName    0
# Brand          0
# Raw_Weight     0
# Country        0
# OrderDate      0
# UnitPrice      0
# dtype: int64

# %%
retail.to_csv("Online_Retail_Cleaned.csv", index=False)

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      3000 non-null   object
#  1   CustomerID   3000 non-null   int64
#  2   ProductName  3000 non-null   object
#  3   Brand        3000 non-null   object
#  4   Raw_Weight   3000 non-null   object
#  5   Country      3000 non-null   object
#  6   OrderDate    3000 non-null   datetime64[ns]
#  7   UnitPrice    3000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 187.6+ KB

# %%
retail.describe()
# Out:
#          CustomerID                   OrderDate
# count   3000.000000                        3000
# mean    9989.842333  2025-02-04 01:28:19.200000
# min     5011.000000         2024-02-05 00:00:00
# 25%     7454.750000         2024-08-10 18:00:00
# 50%    10066.000000         2025-02-01 00:00:00
# 75%    12527.250000         2025-08-06 00:00:00
# max    14998.000000         2026-02-04 00:00:00
# std     2871.959873                         NaN

# %%
retail.describe(include="object")
# Out:
#            OrderID ProductName     Brand  Raw_Weight Country UnitPrice
# count         3000        3000      3000        3000    3000      3000
# unique        2992        2710      1081         727      68      1591
# top     REC-133930    NotKnown  Notknown  Subjective  France  Notknown
# freq             2          96       335         512    1611       385

# %%
retail["UnitPrice"].describe()
# Out:
# count         3000
# unique        1591
# top       Notknown
# freq           385
# Name: UnitPrice, dtype: object

# %%
# EDA Exploratory Data analysis
import matplotlib.pyplot as plt

retail["Country"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Countries")
plt.xlabel("Country")
plt.ylabel("Orders")
plt.show()

# %%
retail[retail["Country"]=="Gb"]
retail.head(10)
# Out:
#       OrderID  CustomerID                           ProductName  \
# 0  REC-861088        6120                                 Perly
# 1  REC-900952       12550                  Prince Goût Chocolat
# 2  REC-595965        6705  Excellence Noir Prodigieux 90% Cacao
# 3  REC-942653        8645                                 Tonik
# 4  REC-885998       14430                                Sésame
# 5  REC-674324        6760              Шоколад 85% какаова маса
# 6  REC-867660        8420         CRISTALINE Eau De Source 0.5L
# 7  REC-448132        9144                               Henry’s
# 8  REC-202400       10397                    Milk chocolate bar
# 9  REC-386572       13888        Organic 70% Dark Chocolate Bar
#
#                    Brand Raw_Weight  Country  OrderDate UnitPrice
# 0                  Perly      100 g  Morocco 2024-02-22     13.18
# 1                     LU      300 g  Algeria 2024-11-13       1.5
# ...

# %%
retail["Country"].value_counts().head(10)
# Out:
# Country
# France            1611
# United Kingdom     366
# Belgium            243
# Morocco            137
# Spain               85
# Germany             75
# Austria             56
# Bulgaria            52
# Italy               39
# Mexico              33
# Name: count, dtype: int64

# %%
retail["Brand"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Selling Brands")
plt.xlabel("Brands")
plt.ylabel("orders")
plt.show()

# %%
retail["ProductName"].value_counts().head(7).plot(kind="bar")
plt.title("Highest selling products")
plt.xlabel("Productname")
plt.ylabel("Orders")
plt.show()

# %%
retail["UnitPrice"].describe()
# Out:
# count         3000
# unique        1591
# top       Notknown
# freq           385
# Name: UnitPrice, dtype: object

# %%
retail.isnull().sum()
# Out:
# OrderID        0
# CustomerID     0
# ProductName    0
# Brand          0
# Raw_Weight     0
# Country        0
# OrderDate      0
# UnitPrice      0
# dtype: int64

# %%
retail["UnitPrice"] = retail["UnitPrice"].replace("Notknown", pd.NA)
retail["UnitPrice"] = pd.to_numeric(retail["UnitPrice"], errors="coerce")
retail["UnitPrice"].dtype
# Out:
# dtype('float64')

# %%
retail["UnitPrice"].hist(bins=30)
plt.title("Distribution of Unit Price")
plt.show()

# %%
retail["Month"] = retail["OrderDate"].dt.month_name()
retail["Month"].value_counts().plot(kind="bar")
plt.xlabel("Month")
plt.ylabel("Orders")
plt.show()

# %%
retail["Year"]=retail["OrderDate"].dt.year
retail["Year"].value_counts().plot(kind="bar")
plt.xlabel("year")
plt.ylabel("Order")
plt.show()

# %%
retail["Raw_Weight"].value_counts().head(20)
# Out:
# Raw_Weight
# Subjective    512
# 100 g         159
# 200 g         136
# 150 g         110
# 300 g          84
# 100g           62
# 250 g          59
# 125 g          49
# 150g           42
# 200g           38
# 400 g          37
# 250g           31
# 500 g          30
# 170 g          27
# 125g           26
# 180 g          26
# 300g           23
# 85 g           23
# 50 g           21
# 175 g          20
# Name: count, dtype: int64

# %%
retail["CustomerID"].unique()
# Out:
# array([ 6120, 12550,  6705, ..., 11134, 13739, 13398], dtype=int64)

# %%
retail["CustomerID"].value_counts().head(10)
# Out:
# CustomerID
# 6608     4
# 5746     4
# 9141     4
# 13035    3
# 6302     3
# 6007     3
# 5940     3
# 10754    3
# 8496     3
# 9705     3
# Name: count, dtype: int64

# %%
retail.groupby("Country")["UnitPrice"].mean().sort_values(ascending=False).head(10)
# Out:
# Country
# Isle Of Man    23.4800
# Serbia         23.3700
# Brazil         23.1800
# Cape-Verde     23.0700
# Itit           21.4200
# Greece         20.6000
# Chile          20.5400
# Poland         20.0300
# China          17.7300
# Netherlands    17.1125
# Name: UnitPrice, dtype: float64

# %%
retail.groupby("Brand")["UnitPrice"].mean().sort_values(ascending=False).head(10)
# Out:
# Brand
# Tyrells                                      24.99
# FontanedaMondelez                            24.82
# TobleroneMondlez                             24.82
# Tesco finest                                 24.80
# GranolaLu                                    24.79
# Brun                                         24.75
# LU Mondelez Mondelez International           24.73
# Jardin Bio                                   24.72
# GrafschafterLidlMaitre Jean PierreTastino    24.71
# BJORG BIO NUTRI                              24.70
# Name: UnitPrice, dtype: float64

# %% [markdown]
# retail.nlargest(10, "UnitPrice")[["ProductName", "Brand", "Country", "UnitPrice"]]

# %%
# Most Expensive Products
retail.nlargest(10, "UnitPrice")[["ProductName", "Brand", "Country", "UnitPrice"]]
# Out:
#                                             ProductName            Brand  \
# 413                              Mature Cheddar & Chive          Tyrells
# 1796                               Original Stapelchips        Snack Day
# 1896                  Walkers Cheese & Onion Crisps 6pk          Walkers
# 2444                     Chocolate 52% especial postres         Notknown
# 1621                        Biscuits Épeautre et Sésame        Carrefour
# 2025  NESTLE LES RECETTES DE L'ATELIER - Carrés dégu...         Notknown
# 1654                                     Belvita Muesli  BelvitaMondelez
# 2060                            Peak Fish Crackers 250G            Gulln
# 177                             Gingembre saveur citron            Gerbl
# 891   LOTUS BISCOFF Speculoos Original Pocket - 186g...            Lotus
#
#              Country  UnitPrice
# 413           France      24.99
# 1796          France      24.99
# 1896  United Kingdom      24.93
# 2444          France      24.93
# ...

# %%
#most cheapest products
retail.nsmallest(10, "UnitPrice")[["ProductName", "Brand", "Country", "UnitPrice"]]
# Out:
#                                ProductName  \
# 772                 Digestive sin azúcares
# 96              Goûter pépites de chocolat
# 1507                     Pure fresh mentos
# 241                 Baiocchi nocciola 260g
# 302                                 Roudor
# 1306  Glico Mikado & Go - Chocolat au lait
# 2894                             Neo giant
# 920             Doritos Cool Original 180g
# 1947             Excellence Dark 70% Cocoa
# 65          Krit krititas galletas saladas
#
#                                                   Brand  Country  UnitPrice
# 772                                               Gulln    Spain       1.00
# 96                                             Notknown  Belgium       1.01
# 1507                                             Mentos    Spain       1.01
# 241   Barilla Mulino Bianco  Barilla  Barilla G e R ...   France       1.02
# 302                                           St Michel   France       1.02
# ...

# %%
retail["UnitPrice"].value_counts().head(10)
retail["UnitPrice"].isnull().sum()
# Out:
# 385

# %%
retail = retail.dropna(subset=["UnitPrice"])

# %%
retail["UnitPrice"].isnull().sum()
# Out:
# 0

# %%
retail.shape
# Out:
# (2615, 10)

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2615 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      2615 non-null   object
#  1   CustomerID   2615 non-null   int64
#  2   ProductName  2615 non-null   object
#  3   Brand        2615 non-null   object
#  4   Raw_Weight   2615 non-null   object
#  5   Country      2615 non-null   object
#  6   OrderDate    2615 non-null   datetime64[ns]
#  7   UnitPrice    2615 non-null   float64
#  8   Month        2615 non-null   object
#  9   Year         2615 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(6)
# memory usage: 214.5+ KB

# %%
retail["UnitPrice"].describe()
# Out:
# count    2615.000000
# mean       12.992417
# std         6.963856
# min         1.000000
# 25%         6.985000
# 50%        13.160000
# 75%        18.960000
# max        24.990000
# Name: UnitPrice, dtype: float64
